# %% [markdown]
# # Evaluation of oversamplers with a set of classifiers on one database
#
# In this notebook we give an example of optimizing oversamplers and classifiers for given dataset.

# %%
import os.path

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

import smote_variants as sv

import imbalanced_databases as imbd

# %%
# the evaluation procedure uses a directory for caching

cache_path= os.path.join(os.path.expanduser('~'), 'smote_test')

if not os.path.exists(cache_path):
    os.makedirs(cache_path)

# %%
# specifying the dataset to be used

dataset= imbd.load_glass0()

# %%
# specifying the classifiers

knn_classifier= KNeighborsClassifier()
dt_classifier= DecisionTreeClassifier()

# %%
# executing the evaluation using 5 parallel jobs and at most 35 random but meaningful parameter combinations
# with the 5 quickest oversamplers

results= sv.evaluate_oversamplers(datasets= [dataset],
                                    samplers= sv.get_n_quickest_oversamplers(5),
                                    classifiers= [knn_classifier, dt_classifier],
                                    cache_path= cache_path,
                                    n_jobs= 5,
                                    max_samp_par_comb= 35)
# Out:
# 2022-03-27 16:02:06,725:INFO:creating cache directory
# 2022-03-27 16:02:06,728:INFO:dataset: glass0, samplings_available: False, evaluations_available: False
# 2022-03-27 16:02:06,728:INFO:doing the folding
# 2022-03-27 16:02:06,729:INFO:Folding doing folding folding_glass0.pickle
# 2022-03-27 16:02:06,734:INFO:Folding dumping to file folding_glass0.pickle
# 2022-03-27 16:02:06,738:INFO:do the samplings
# 2022-03-27 16:02:06,738:INFO:create sampling objects, random_state:
# 2022-03-27 16:02:06,739:INFO:samplers: [<class 'smote_variants._smote_variants.SPY'>, <class 'smote_variants._smote_variants.OUPS'>, <class 'smote_variants._smote_variants.SMOTE_D'>, <class 'smote_variants._smote_variants.NT_SMOTE'>, <class 'smote_variants._smote_variants.Gazzah'>]
# 2022-03-27 16:02:06,740:INFO:[{'n_neighbors': 3, 'threshold': 0.3}, {'n_neighbors': 3, 'threshold': 0.5}, {'n_neighbors': 3, 'threshold': 0.7}, {'n_neighbors': 5, 'threshold': 0.3}, {'n_neighbors': 5, 'threshold': 0.5}, {'n_neighbors': 5, 'threshold': 0.7}, {'n_neighbors': 7, 'threshold': 0.3}, {'n_neighbors': 7, 'threshold': 0.5}, {'n_neighbors': 7, 'threshold': 0.7}]
# 2022-03-27 16:02:06,742:INFO:random_indices: [2 5 3 4 7 8 1 0 6]
# 2022-03-27 16:02:06,743:INFO:[{'n_neighbors': 3, 'threshold': 0.7}, {'n_neighbors': 5, 'threshold': 0.7}, {'n_neighbors': 5, 'threshold': 0.3}, {'n_neighbors': 5, 'threshold': 0.5}, {'n_neighbors': 7, 'threshold': 0.5}, {'n_neighbors': 7, 'threshold': 0.7}, {'n_neighbors': 3, 'threshold': 0.5}, {'n_neighbors': 3, 'threshold': 0.3}, {'n_neighbors': 7, 'threshold': 0.3}]
# 2022-03-27 16:02:06,743:INFO:{'n_neighbors': 3, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02:06,744:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.7)])
# 2022-03-27 16:02:06,746:INFO:{'n_neighbors': 5, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02:06,747:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.7)])
# 2022-03-27 16:02:06,747:INFO:{'n_neighbors': 5, 'threshold': 0.3, 'random_state': None}
# 2022-03-27 16:02:06,748:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.3)])
# 2022-03-27 16:02:06,748:INFO:{'n_neighbors': 5, 'threshold': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,749:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.5)])
# 2022-03-27 16:02:06,750:INFO:{'n_neighbors': 7, 'threshold': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,750:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.5)])
# 2022-03-27 16:02:06,751:INFO:{'n_neighbors': 7, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02
'n_components': 4, 'proportion': 1.0}, {'n_components': 5, 'proportion': 0.5}, {'n_components': 3, 'proportion': 0.25}, {'n_components': 5, 'proportion': 2.0}, {'n_components': 3, 'proportion': 0.75}, {'n_components': 2, 'proportion': 2.0}, {'n_components': 5, 'proportion': 0.25}, {'n_components': 2, 'proportion': 0.75}, {'n_components': 5, 'proportion': 1.0}, {'n_components': 4, 'proportion': 1.5}, {'n_components': 3, 'proportion': 2.0}, {'n_components': 5, 'proportion': 0.1}, {'n_components': 3, 'proportion': 0.5}, {'n_components': 3, 'proportion': 1.5}, {'n_components': 4, 'proportion': 0.1}, {'n_components': 2, 'proportion': 0.1}, {'n_components': 2, 'proportion': 0.5}, {'n_components': 4, 'proportion': 2.0}]
# 2022-03-27 16:02:06,811:INFO:{'n_components': 4, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,811:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:06,812:INFO:{'n_components': 2, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:06,812:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:06,814:INFO:{'n_components': 5, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:06,814:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:06,814:INFO:{'n_components': 5, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:06,815:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:06,816:INFO:{'n_components': 3, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:06,817:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:06,817:INFO:{'n_components': 2, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:06,818:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:06,819:INFO:{'n_components': 2, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:06,819:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:06,820:INFO:{'n_components': 3, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:06,821:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:06,821:INFO:{'n_components': 4, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:06,822:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:06,823:INFO:{'n_components': 4, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:06,823:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:06,824:INFO:{'n_components': 4, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:06,825:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:06,826:INFO:{'n_components': 5, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,826:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:06,827:INFO:{'n_components': 3, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:06,828:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:06,828:INFO:{'n_components': 5, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:06,829:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:06,829:INFO:{'n_components': 3, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:06,830:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:06,830:INFO:{'n_components': 2, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:06,830:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:06,831:INFO:{'n_components': 5, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:06,831:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:06,832:INFO:{'n_components': 2, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:06,832:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:06,833:INFO:{'n_components': 5, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:06,833:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:06,834:INFO:{'n_components': 4, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:06,834:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:06,835:INFO:{'n_components': 3, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:06,836:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:06,836:INFO:{'n_components': 5, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:06,837:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:06,838:INFO:{'n_components': 3, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,838:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:06,838:INFO:{'n_components': 3, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:06,839:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:06,839:INFO:{'n_components': 4, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:06,840:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:06,840:INFO:{'n_components': 2, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:06,841:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:06,841:INFO:{'n_components': 2, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:06,842:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:06,842:INFO:{'n_components': 4, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:06,843:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:06,843:INFO:executing 72 sampling in parallel
# 2022-03-27 16:02:10,549:INFO:do the evaluations
# 2022-03-27 16:02:10,550:INFO:create classifier jobs
# 2022-03-27 16:02:10,551:INFO:{'n_neighbors': 7, 'threshold': 0.3, 'random_state': None}
# 2022-03-27 16:02:10,552:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.3)])
# 2022-03-27 16:02:10,553:INFO:{'n_neighbors': 3, 'threshold': 0.3, 'random_state': None}
# 2022-03-27 16:02:10,554:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.3)])
# 2022-03-27 16:02:10,556:INFO:{'n_neighbors': 3, 'threshold': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,556:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.5)])
# 2022-03-27 16:02:10,557:INFO:{'n_neighbors': 7, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02:10,558:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.7)])
# 2022-03-27 16:02:10,560:INFO:{'n_neighbors': 7, 'threshold': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,560:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.5)])
# 2022-03-27 16:02:10,562:INFO:{'n_neighbors': 5, 'threshold': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,562:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.5)])
# 2022-03-27 16:02:10,564:INFO:{'n_neighbors': 5, 'threshold': 0.3, 'random_state': None}
# 2022-03-27 16:02:10,565:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.3)])
# 2022-03-27 16:02:10,566:INFO:{'n_neighbors': 5, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02:10,567:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.7)])
# 2022-03-27 16:02:10,568:INFO:{'n_neighbors': 3, 'threshold': 0.7, 'random_state': None}
# 2022-03-27 16:02:10,568:INFO:Sampling sampler parameter string OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.7)])
# 2022-03-27 16:02:10,569:INFO:{'n_components': 4, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,570:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,571:INFO:{'n_components': 3, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,572:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,573:INFO:{'n_components': 2, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,574:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,575:INFO:{'n_components': 5, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,576:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,577:INFO:{'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,577:INFO:Sampling sampler parameter string OrderedDict([('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,579:INFO:{'k': 5, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,580:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,582:INFO:{'k': 7, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,583:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,584:INFO:{'k': 3, 'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,586:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,587:INFO:{'proportion': 2.0, 'random_state': None}
# 2022-03-27 16:02:10,588:INFO:Sampling sampler parameter string OrderedDict([('proportion', 2.0), ('random_state', None)])
# 2022-03-27 16:02:10,590:INFO:{'n_components': 3, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,590:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,592:INFO:{'n_components': 4, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,592:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,594:INFO:{'n_components': 5, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,594:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,595:INFO:{'n_components': 2, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,596:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,598:INFO:{'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,599:INFO:Sampling sampler parameter string OrderedDict([('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,600:INFO:{'k': 5, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,601:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,602:INFO:{'k': 3, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,603:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,605:INFO:{'k': 7, 'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,606:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,607:INFO:{'proportion': 1.5, 'random_state': None}
# 2022-03-27 16:02:10,608:INFO:Sampling sampler parameter string OrderedDict([('proportion', 1.5), ('random_state', None)])
# 2022-03-27 16:02:10,610:INFO:{'n_components': 5, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,611:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,612:INFO:{'n_components': 4, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,612:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,613:INFO:{'n_components': 2, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,614:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,616:INFO:{'n_components': 3, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,617:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,619:INFO:{'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,620:INFO:Sampling sampler parameter string OrderedDict([('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,622:INFO:{'k': 5, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,622:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,624:INFO:{'k': 7, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,630:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,631:INFO:{'k': 3, 'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,633:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,635:INFO:{'proportion': 1.0, 'random_state': None}
# 2022-03-27 16:02:10,636:INFO:Sampling sampler parameter string OrderedDict([('proportion', 1.0), ('random_state', None)])
# 2022-03-27 16:02:10,638:INFO:{'n_components': 2, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,639:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,640:INFO:{'n_components': 3, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,641:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,643:INFO:{'n_components': 4, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,644:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,645:INFO:{'n_components': 5, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,683:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,684:INFO:{'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,685:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,686:INFO:{'k': 5, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,687:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,688:INFO:{'k': 3, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,689:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,690:INFO:{'k': 7, 'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,691:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,692:INFO:{'proportion': 0.75, 'random_state': None}
# 2022-03-27 16:02:10,692:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.75), ('random_state', None)])
# 2022-03-27 16:02:10,694:INFO:{'n_components': 2, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,694:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,695:INFO:{'n_components': 3, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,696:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,697:INFO:{'n_components': 5, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,698:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,699:INFO:{'n_components': 4, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,700:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,701:INFO:{'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,702:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,704:INFO:{'k': 5, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,704:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,705:INFO:{'k': 7, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,706:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,708:INFO:{'k': 3, 'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,708:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,714:INFO:{'proportion': 0.5, 'random_state': None}
# 2022-03-27 16:02:10,715:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.5), ('random_state', None)])
# 2022-03-27 16:02:10,718:INFO:{'n_components': 5, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,720:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,722:INFO:{'n_components': 3, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,723:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,725:INFO:{'n_components': 4, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,726:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,728:INFO:{'n_components': 2, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,729:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,731:INFO:{'proportion': 0.25, 'random_state': None}
# ["('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.3)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.3)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.3)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.3)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.5)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.5)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.7)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.7)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.5)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 7), ('random_state', None), ('threshold', 0.5)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.5)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.5)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.3)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.3)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.7)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 5), ('random_state', None), ('threshold', 0.7)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.7)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_neighbors', 3), ('random_state', None), ('threshold', 0.7)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 4), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 4), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 3), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 3), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 2), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 2), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 5), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 5), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 5), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 5), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 7), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 7), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 3), ('proportion', 2.0), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 3), ('proportion', 2.0), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ...
# ["('glass0', OrderedDict([('n_components', 3), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 3), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 4), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 4), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 2), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 2), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# 2022-03-27 16:02:10,733:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,735:INFO:{'k': 5, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,736:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,738:INFO:{'k': 3, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,739:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,741:INFO:{'k': 7, 'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,742:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,744:INFO:{'proportion': 0.25, 'random_state': None}
# 2022-03-27 16:02:10,745:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.25), ('random_state', None)])
# 2022-03-27 16:02:10,746:INFO:{'n_components': 2, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,747:INFO:Sampling sampler parameter string OrderedDict([('n_components', 2), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,748:INFO:{'n_components': 4, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,749:INFO:Sampling sampler parameter string OrderedDict([('n_components', 4), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,751:INFO:{'n_components': 5, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,752:INFO:Sampling sampler parameter string OrderedDict([('n_components', 5), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,754:INFO:{'n_components': 3, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,755:INFO:Sampling sampler parameter string OrderedDict([('n_components', 3), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,757:INFO:{'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,767:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,769:INFO:{'k': 7, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,770:INFO:Sampling sampler parameter string OrderedDict([('k', 7), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,772:INFO:{'k': 3, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,773:INFO:Sampling sampler parameter string OrderedDict([('k', 3), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,774:INFO:{'k': 5, 'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,775:INFO:Sampling sampler parameter string OrderedDict([('k', 5), ('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,776:INFO:{'proportion': 0.1, 'random_state': None}
# 2022-03-27 16:02:10,777:INFO:Sampling sampler parameter string OrderedDict([('proportion', 0.1), ('random_state', None)])
# 2022-03-27 16:02:10,778:INFO:executing 72 evaluation jobs in parallel
# ["('glass0', OrderedDict([('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 5), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 5), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 3), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 3), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 7), ('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 7), ('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('proportion', 0.25), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('proportion', 0.25), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 2), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 2), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 4), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 4), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 5), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 5), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('n_components', 3), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('n_components', 3), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 7), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 7), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 3), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 3), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('k', 5), ('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('k', 5), ('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# ["('glass0', OrderedDict([('proportion', 0.1), ('random_state', None)]), 'KNeighborsClassifier', OrderedDict([('algorithm', 'auto'), ('leaf_size', 30), ('metric', 'minkowski'), ('metric_params', None), ('n_jobs', None), ('n_neighbors', 5), ('p', 2), ('weights', 'uniform')]))", "('glass0', OrderedDict([('proportion', 0.1), ('random_state', None)]), 'DecisionTreeClassifier', OrderedDict([('ccp_alpha', 0.0), ('class_weight', None), ('criterion', 'gini'), ('max_depth', None), ('max_features', None), ('max_leaf_nodes', None), ('min_impurity_decrease', 0.0), ('min_samples_leaf', 1), ('min_samples_split', 2), ('min_weight_fraction_leaf', 0.0), ('random_state', None), ('splitter', 'best')]))"]
# 2022-03-27 16:02:13,347:INFO:concatenating the results
# 2022-03-27 16:02:13,496:INFO:aggregating the results

# %%
# determining oversampler and classifier combination with highest AUC score

highest_auc_score= results['auc'].idxmax()

# %%
# querying classifier and oversampler parameters with highest AUC score

cl, cl_par, samp, samp_par= results.loc[highest_auc_score][['classifier',
                                                           'classifier_parameters_auc',
                                                           'sampler',
                                                           'sampler_parameters_auc']]

# %%
# instantiating oversampler and classifier objects providing the highest AUC score

samp_obj= getattr(sv, samp)(**eval(samp_par))
cl_obj= eval(cl)(**eval(cl_par))

# %%
# oversampling the entire dataset and fitting a classifier

X_samp, y_samp= samp_obj.sample(dataset['data'], dataset['target'])
cl_obj.fit(X_samp, y_samp)
# Out:
# 2022-03-27 16:02:35,149:INFO:OUPS: Running sampling via ('OUPS', "{'proportion': 2.0, 'n_jobs': 1, 'random_state': None}")
# C:\Users\FamiliaNatelloMedina\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# KNeighborsClassifier()
